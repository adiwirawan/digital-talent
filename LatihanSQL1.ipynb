# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# # 1. Prepare a list of offices sorted by country, state, city.

# %%
run("""
SELECT * FROM offices order by country, state, city
""")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# # 2.How many employees are there in the company?

# %%
run("""
SELECT count(DISTINCT(employeeNumber)) as "JUMLAH" FROM `employees`
""")
# Out:
#    JUMLAH
# 0      23

# %% [markdown]
# # 3. What is the total of payments received?

# %%
run("""
SELECT sum(amount) as "TOTAL" FROM `payments`
""")
# Out:
#         TOTAL
# 0  8853839.23

# %% [markdown]
# # 4. List the product lines that contain 'Cars'.

# %%
run("""
SELECT * FROM `productlines` WHERE productLine like '%Cars%'
""")
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1  Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None

# %% [markdown]
# # 5. Report total payments for October 28, 2004.

# %%
run("""
SELECT amount FROM payments where paymentDate='2004-10-28'
""")
# Out:
#      amount
# 0  47411.33

# %% [markdown]
# # 6. Report those payments greater than \$100,000.

# %%
run("""
SELECT * FROM `payments` WHERE amount > 100000
""")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# # 7. List the products in each product line.

# %%
run("""
SELECT productLine, productCode, productName FROM products order by productline
""")
# Out:
#           productLine productCode                                productName
# 0        Classic Cars    S18_3482                      1976 Ford Gran Torino
# 1        Classic Cars    S24_2840        1958 Chevy Corvette Limited Edition
# 2        Classic Cars    S24_2887                          1952 Citroen-15CV
# 3        Classic Cars    S24_2972                    1982 Lamborghini Diablo
# 4        Classic Cars    S24_3191                  1969 Chevrolet Camaro Z28
# 5        Classic Cars    S18_2238             1998 Chrysler Plymouth Prowler
# 6        Classic Cars    S18_1984                           1995 Honda Civic
# 7        Classic Cars    S18_1889                1948 Porsche 356-A Roadster
# 8        Classic Cars    S24_3371                  1971 Alpine Renault 1600s
# 9        Classic Cars    S24_2766                         1949 Jaguar XK 120
# 10       Classic Cars    S18_2870               1999 Indy 500 Monte Carlo SS
# ...

# %% [markdown]
# # 8. How many products in each product line?

# %%
run("""
SELECT productLine,count(*) as "jumlah" FROM products group by productLine
""")
# Out:
#         productLine  jumlah
# 0      Classic Cars      38
# 1       Motorcycles      13
# 2            Planes      12
# 3             Ships       9
# 4            Trains       3
# 5  Trucks and Buses      11
# 6      Vintage Cars      24

# %% [markdown]
# # 9. What is the minimum payment received?

# %%
run("""
SELECT min(amount) as "Minimum Payment" FROM `payments`
""")
# Out:
#    Minimum Payment
# 0           615.45

# %% [markdown]
# # 10. List all payments greater than twice the average payment.

# %%
run("""
SELECT * FROM `payments` WHERE amount > (select 2*avg(amount) from payments)
""")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %% [markdown]
# # 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run("""
SELECT AVG(MSRP-buyPrice) FROM products
""")
# Out:
#    AVG(MSRP-buyPrice)
# 0           46.043545

# %% [markdown]
# # 12. How many distinct products does ClassicModels sell?

# %%
run("""
SELECT count(DISTINCT productName) as "Distinct Products" FROM products
""")
# Out:
#    Distinct Products
# 0                110

# %% [markdown]
# # 13. Report the name and city of customers who don't have sales representatives?

# %%
run("""
SELECT customerName,city,salesRepEmployeeNumber FROM customers WHERE salesRepEmployeeNumber IS NULL
""")
# Out:
#                       customerName              city salesRepEmployeeNumber
# 0               Havel & Zbyszek Co          Warszawa                   None
# 1                Porto Imports Co.            Lisboa                   None
# 2       Asian Shopping Network, Co         Singapore                   None
# 3                  Natürlich Autos         Cunewalde                   None
# 4                    ANG Resellers            Madrid                   None
# 5         Messner Shopping Network         Frankfurt                   None
# 6                Franken Gifts, Co           München                   None
# 7                BG&E Collectables          Fribourg                   None
# 8                 Schuyler Imports         Amsterdam                   None
# 9                 Der Hund Imports            Berlin                   None
# 10       Cramer Spezialitäten, Ltd       Brandenburg                   None
# ...

# %% [markdown]
# # 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting

# %%
run("""
SELECT CONCAT(firstName,' ',lastName) AS Nama, jobTitle FROM employees WHERE jobTitle LIKE '%VP%' or jobTitle LIKE '%Manager%' 
""")
# Out:
#                 Nama              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)
